# %% [markdown]
# Here, we will attempt to profile the performance of the AI we just wrote

# %%
import pandas

# %%
! python -m cProfile wrapper.py --ai_vs_ai 1 > log.txt

# %%
! grep -A 10000 'ncalls' log.txt | cut -c 1-46 > table.txt     
! grep -A 10000 'ncalls' log.txt | cut -c 46- > table2.txt

# %%
! head table.txt
# Out:
#    ncalls  tottime  percall  cumtime  percall
#       319    0.001    0.000    0.001    0.000
#       150    0.000    0.000    0.000    0.000
#       150    0.000    0.000    0.002    0.000
#       150    0.000    0.000    0.001    0.000
#       319    0.001    0.000    0.001    0.000
#       147    0.000    0.000    0.000    0.000
#       169    0.000    0.000    0.001    0.000
#     198/1    0.000    0.000    0.263    0.263
#      1528    0.001    0.000    0.001    0.000

# %%
! head table2.txt
# Out:
#  filename:lineno(function)
#  <frozen importlib._bootstrap>:102(release)
#  <frozen importlib._bootstrap>:142(__init__)
#  <frozen importlib._bootstrap>:146(__enter__)
#  <frozen importlib._bootstrap>:153(__exit__)
#  <frozen importlib._bootstrap>:159(_get_module_lock)
#  <frozen importlib._bootstrap>:173(cb)
#  <frozen importlib._bootstrap>:178(_lock_unlock_module)
#  <frozen importlib._bootstrap>:197(_call_with_frames_removed)
#  <frozen importlib._bootstrap>:208(_verbose_message)

# %%
df0 = pandas.read_csv('table.txt', sep='\s+')
df1 = pandas.read_csv('table2.txt') 
df = df0.join(df1)

# %%
df.sort_values('cumtime', ascending=F)
# Out:
#        ncalls  tottime  percall  cumtime  percall.1  \
# 496       116    0.000    0.000    0.000      0.000
# 616         1    0.000    0.000    0.000      0.000
# 617         1    0.000    0.000    0.000      0.000
# 618         1    0.000    0.000    0.000      0.000
# 619         1    0.000    0.000    0.000      0.000
# 620         1    0.000    0.000    0.000      0.000
# 621         1    0.000    0.000    0.000      0.000
# 624       330    0.000    0.000    0.000      0.000
# 626        22    0.000    0.000    0.000      0.000
# 628         1    0.000    0.000    0.000      0.000
# 629        88    0.000    0.000    0.000      0.000
# 630         4    0.000    0.000    0.000      0.000
# 631         2    0.000    0.000    0.000      0.000
# 632       116    0.000    0.000    0.000      0.000
# 633       341    0.000    0.000    0.000      0.000
# 634         1    0.000    0.000    0.000      0.000
# 635         1    0.000    0.000    0.000      0.000
# 636         1    0.000    0.000    0.000      0.000
# 638         1    0.000    0.000    0.000      0.000
# 639         1    0.000    0.000    0.000      0.000
# 642         1    0.000    0.000    0.000      0.000
# 643         1    0.000    0.000    0.000      0.000
# 644         1    0.000    0.000    0.000      0.000
# 645         1    0.000    0.000    0.000      0.000
# 614         1    0.000    0.000    0.000      0.000
# 613         1    0.000    0.000    0.000      0.000
# 612         1    0.000    0.000    0.000      0.000
# 611         3    0.000    0.000    0.000      0.000
# 585         1    0.000    0.000    0.000      0.000
# 586         3    0.000    0.000    0.000      0.000
# ..        ...      ...      ...      ...        ...
# 683     98769    0.062    0.000    0.062      0.000
# 898     98769    0.068    0.000    0.068      0.000
# 69      18/17    0.000    0.000    0.159      0.009
# 860     18/17    0.157    0.009    0.159      0.009
# 892    394923    0.160    0.000    0.160      0.000
# 21    140/138    0.000    0.000    0.164      0.001
# 819         1    0.000    0.000    0.203      0.203
# 245         1    0.000    0.000    0.219      0.219
# 35     738/87    0.001    0.000    0.241      0.003
# 875     310/7    0.000    0.000    0.246      0.035
# 105         1    0.000    0.000    0.248      0.248
# 334         1    0.000    0.000    0.256      0.256
# 490         1    0.000    0.000    0.257      0.257
# 34      150/1    0.001    0.000    0.263      0.263
# 23      140/1    0.001    0.000    0.263      0.263
# 7       198/1    0.000    0.000    0.263      0.263
# 33      150/1    0.001    0.000    0.263      0.263
# 60      119/1    0.000    0.000    0.263      0.263
# 557         2    0.000    0.000    0.268      0.134
# 684     98769    0.123    0.000    0.283      0.000
# 102         5    0.001    0.000    0.429      0.086
# 336  12820169    2.424    0.000    2.424      0.000
# 899   3664071    5.829    0.000    8.253      0.000
# 686     33033    1.568    0.000   10.234      0.000
# 498        11    0.000    0.000   11.270      1.025
# 637        22    0.872    0.040   11.270      0.512
# 500         1    0.000    0.000   11.286     11.286
# 559         1    0.000    0.000   11.288     11.288
# 846         1    0.000    0.000   11.551     11.551
# 883     125/1    0.003    0.000   11.551     11.551
#
#                              filename:lineno(function)
# 496                             game.py:32(<listcomp>)
# 616                            pickle.py:345(_Pickler)
# 617                          pickle.py:64(PickleError)
# 618                        pickle.py:68(PicklingError)
# 619                      pickle.py:75(UnpicklingError)
# 620                                pickle.py:88(_Stop)
# 621                          pickle.py:986(_Unpickler)
# 624                         players.py:120(<listcomp>)
# 626                         players.py:145(<listcomp>)
# 628                              players.py:15(Player)
# 629                         players.py:159(<listcomp>)
# 630                            players.py:21(__init__)
# 631                               players.py:35(clean)
# 632                                 players.py:39(peg)
# 633                            players.py:42(__repr__)
# 634            players.py:47(NondeterministicAIPlayer)
# 635                         players.py:61(HumanPlayer)
# 636                            players.py:94(AIPlayer)
# 638                     polynomial.py:1517(Polynomial)
# 639                      polynomial.py:22(RankWarning)
# 642                          polynomial.py:940(poly1d)
# 643                          polyutils.py:45(<module>)
# 644                       polyutils.py:58(RankWarning)
# 645                         polyutils.py:62(PolyError)
# 614                           pickle.py:220(_Unframer)
# 613                             pickle.py:184(_Framer)
# 612                          pickle.py:181(<listcomp>)
# 611                                  os.py:744(decode)
# 585                           numeric.py:2978(_setdef)
# 586                         numeric.py:365(extend_all)
# ..                                                 ...
# 683                            score.py:24(<listcomp>)
# 898                  {built-in method builtins.sorted}
# 69    <frozen importlib._bootstrap_external>:919(cr...
# 860              {built-in method _imp.create_dynamic}
# 892                     {built-in method builtins.min}
# 21    <frozen importlib._bootstrap>:553(module_from...
# 819                          type_check.py:3(<module>)
# 245                        add_newdocs.py:10(<module>)
# 35    <frozen importlib._bootstrap>:989(_handle_fro...
# 875              {built-in method builtins.__import__}
# 105                          __init__.py:106(<module>)
# 334                                card.py:3(<module>)
# 490                                game.py:1(<module>)
# 34    <frozen importlib._bootstrap>:958(_find_and_l...
# 23    <frozen importlib._bootstrap>:641(_load_unloc...
# 7     <frozen importlib._bootstrap>:197(_call_with_...
# 33    <frozen importlib._bootstrap>:931(_find_and_l...
# 60    <frozen importlib._bootstrap_external>:672(ex...
# 557                                main.py:1(<module>)
# 684                            score.py:25(<listcomp>)
# 102                            __init__.py:1(<module>)
# 336                               card.py:41(__radd__)
# 899                     {built-in method builtins.sum}
# 686                                  score.py:5(score)
# 498                                game.py:5(discards)
# 637                    players.py:99(ask_for_discards)
# 500                          game.py:73(game_with_gui)
# 559                                    main.py:5(main)
# 846                             wrapper.py:1(<module>)
# 883                    {built-in method builtins.exec}
#
# [993 rows x 6 columns]
